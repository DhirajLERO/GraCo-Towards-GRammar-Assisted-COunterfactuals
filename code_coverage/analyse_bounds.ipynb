# %%
import pandas as pd
import copy
import numpy as np

# %%
data = pd.read_csv("output/NSGAIII_test/0/final_gen.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                          Phenotype  \
# 0           0  x[8] += 1 ; x[7] -= 4 ; x[6] -= 2 ; x[3] -= 1 ...
# 1           1      x[1] ^= 1 ; x[7] -= 2 ; x[3] -= 7 ; x[0] += 6
# 2           2                                          x[7] -= 4
# 3           3    x[0] += 1 ; x[0] -= 1 ; x[7] -= 9 ; x[6] *= 0.1
# 4           4                            x[7] -= 9 ; x[6] += 1.0
#
#             o_1           o_2           o_3           o_4
# 0      0.611005      0.201262      0.555556      0.132135
# 1  10000.000000  10000.000000  10000.000000  10000.000000
# 2      0.619294      0.012346      0.111111      0.220980
# 3      0.701089      0.076515      0.222222      0.248381
# 4      0.578744      0.027792      0.222222      0.218773

# %%
data.sort_values(by=['o_1'], inplace=True)

# %%
data.head(20)
# Out:
#      Unnamed: 0                                          Phenotype       o_1  \
# 450         450  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 7 ...  0.388552
# 13           13  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 7 ...  0.397470
# 140         140  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 7 ...  0.397539
# 45           45  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 9 ...  0.439775
# 61           61  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 7 ...  0.462090
# 84           84  x[8] += 6 ; x[7] -= 9 ; x[6] += 2 ; x[0] += 9 ...  0.463029
# 19           19  x[1] ^= 1 ; x[7] -= 9 ; x[6] += 2 ; x[0] += 9 ...  0.467244
# 77           77  x[7] -= 9 ; x[8] += 1 ; x[0] += 9 ; x[7] -= 7 ...  0.470410
# 161         161                  x[7] -= 9 ; x[7] -= 9 ; x[7] -= 8  0.472759
# 32           32  x[8] += 6 ; x[7] -= 9 ; x[6] += 2 ; x[0] += 9 ...  0.505759
# 100         100  x[1] ^= 1 ; x[7] -= 1 ; x[7] -= 4 ; x[7] -= 8 ...  0.508594
# 34           34                  x[7] -= 7 ; x[8] += 5 ; x[7] -= 6  0.516742
# 42           42                x[7] -= 9 ; x[7] -= 8 ; x[6] += 1.0  0.524215
# 59           59                  x[1] ^= 1 ; x[7] -= 9 ; x[7] -= 7  0.526223
# 76           76                              x[7] -= 9 ; x[7] -= 7  0.530726
# 30           30  x[1] ^= 1 ; x[7] -= 8 ; x[7] -= 7 ; x[1] ^= 1 ...  0.534484
# 47           47                              x[7] -= 8 ; x[7] -= 7  0.537248
# 152         152                  x[7] -= 9 ; x[0] += 8 ; x[8] += 1  0.537872
# 38           38  x[8] += 1 ; x[7] -= 4 ; x[6] -= 2 ; x[7] -= 9 ...  0.538549
# 90           90                x[6] += 1.1 ; x[7] -= 7 ; x[7] -= 7  0.543762
#
#           o_2       o_3       o_4
# 450  0.149929  0.333333  0.266325
# 13   0.148955  0.444444  0.264478
# 140  0.148928  0.333333  0.264466
# 45   0.253375  0.555556  0.195289
# 61   0.127323  0.333333  0.245110
# 84   0.318091  0.555556  0.163363
# 19   0.105128  0.333333  0.254646
# 77   0.179792  0.444444  0.287821
# 161  0.076023  0.111111  0.253289
# 32   0.191548  0.444444  0.207104
# 100  0.169753  0.222222  0.180730
# 34   0.151235  0.222222  0.194576
# 42   0.052483  0.222222  0.232883
# 59   0.160494  0.222222  0.175311
# 76   0.049383  0.111111  0.229798
# 30   0.212963  0.333333  0.142288
# 47   0.046296  0.111111  0.226712
# 152  0.096784  0.333333  0.226824
# 38   0.173484  0.444444  0.159170
# 90   0.043224  0.222222  0.223623

# %%
def load_data(data):
    return np.load(data)


def apply_phenotype(array, phenotype):
    # Split the phenotype string into individual operations
    operations = phenotype.split(';')
    x = copy.deepcopy(array)
    # Iterate over each operation and execute it
    for operation in operations:
        # Strip any leading/trailing whitespace from the operation
        operation = operation.strip()
        
        # Use the exec function to execute the operation on the array
        if operation:
            exec(operation)

    return x


def check_bounds(np_array, bounds):
 
    # Ensure the input is a NumPy array
    np_array = np.asarray(np_array)

    # Check if the length of bounds matches the length of the array
    if len(np_array) != len(bounds):
        raise ValueError("Length of bounds must match the length of the numpy array")

    # Iterate over each element and its corresponding bounds
    for idx, (value, (min_bound, max_bound)) in enumerate(zip(np_array, bounds)):
        if not (min_bound <= value <= max_bound):
            return False

    return True

def check_bounds_on_all_phenotype(phenotype_list, o_1_list,  bounds, input_data):
    for i, phenotype in enumerate(phenotype_list):
        evolved_x = apply_phenotype(input_data, phenotype)
        if check_bounds(evolved_x, bounds):
            print("within bounds")
            print("the value of fitness: ", o_1_list[i])
        else:
            print("out of bounds")
            print("the value of fitness: ", o_1_list[i])

bounds = [(18, 80), (0, 1), (0, 3), (0, 2), (0, 3), (0, 2), (100.0, 50000.0), (3, 100), (0, 7)]

# %%
input_data = load_data("output/NSGAIII_test/0/input_data.npy")
phenotype_list = data['Phenotype'].to_list()
o_1_list = data['o_1'].to_list()


check_bounds_on_all_phenotype(phenotype_list, o_1_list,  bounds, input_data)
# Out:
# within bounds
# the value of fitness:  0.3885523676872253
# within bounds
# the value of fitness:  0.3974695205688476
# within bounds
# the value of fitness:  0.3975394368171692
# within bounds
# the value of fitness:  0.4397745728492737
# within bounds
# the value of fitness:  0.4620899558067322
# within bounds
# the value of fitness:  0.4630293846130371
# within bounds
# the value of fitness:  0.4672442674636841
# within bounds
# the value of fitness:  0.4704098701477051
# within bounds
# the value of fitness:  0.4727587103843689
# within bounds
# the value of fitness:  0.5057591199874878
# within bounds
# the value of fitness:  0.5085935294628143
# within bounds
# the value of fitness:  0.5167421698570251
# within bounds
# the value of fitness:  0.5242150723934174
# within bounds
# the value of fitness:  0.5262226462364197
# within bounds
# the value of fitness:  0.5307262539863586
# within bounds
# the value of fitness:  0.5344840288162231
# within bounds
# the value of fitness:  0.5372483134269714
# within bounds
# the value of fitness:  0.5378716289997101
# within bounds
# the value of fitness:  0.5385487377643585
# within bounds
# the value of fitness:  0.5437618494033813
# within bounds
# the value of fitness:  0.5444185137748718
# within bounds
# the value of fitness:  0.545773983001709
# within bounds
# the value of fitness:  0.545773983001709
# within bounds
# the value of fitness:  0.5502513349056244
# within bounds
# the value of fitness:  0.5514947175979614
# within bounds
# the value of fitness:  0.5527783036231995
# within bounds
# the value of fitness:  0.5553711354732513
# within bounds
# the value of fitness:  0.5567284226417542
# within bounds
# the value of fitness:  0.5567333698272705
# within bounds
# the value of fitness:  0.5609543919563293
# within bounds
# the value of fitness:  0.5616709589958191
# within bounds
# the value of fitness:  0.5631860792636871
# within bounds
# the value of fitness:  0.5631860792636871
# within bounds
# the value of fitness:  0.5655544996261597
# within bounds
# the value of fitness:  0.5668303370475769
# within bounds
# the value of fitness:  0.5692503750324249
# within bounds
# the value of fitness:  0.5692503750324249
# within bounds
# the value of fitness:  0.5725346505641937
# within bounds
# the value of fitness:  0.5731555223464966
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5775088667869568
# within bounds
# the value of fitness:  0.5782192349433899
# within bounds
# the value of fitness:  0.5787444114685059
# within bounds
# the value of fitness:  0.5787444114685059
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.5787763595581055
# within bounds
# the value of fitness:  0.579510897397995
# within bounds
# the value of fitness:  0.579853743314743
# within bounds
# the value of fitness:  0.5856927633285522
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.585724264383316
# within bounds
# the value of fitness:  0.5869837403297424
# within bounds
# the value of fitness:  0.5869837403297424
# within bounds
# the value of fitness:  0.5869837403297424
# within bounds
# the value of fitness:  0.5910058319568634
# within bounds
# the value of fitness:  0.5938915312290192
# within bounds
# the value of fitness:  0.5938915312290192
# within bounds
# the value of fitness:  0.5938915312290192
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.5951437652111053
# within bounds
# the value of fitness:  0.6020068526268005
# within bounds
# the value of fitness:  0.6032212674617767
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.603251188993454
# within bounds
# the value of fitness:  0.6100675165653229
# within bounds
# the value of fitness:  0.6100675165653229
# within bounds
# the value of fitness:  0.6100675165653229
# within bounds
# the value of fitness:  0.6110052168369293
# within bounds
# the value of fitness:  0.611272543668747
# within bounds
# the value of fitness:  0.6113027930259705
# within bounds
# the value of fitness:  0.6113027930259705
# within bounds
# the value of fitness:  0.6113027930259705
# within bounds
# the value of fitness:  0.6113027930259705
# within bounds
# the value of fitness:  0.6113027930259705
# within bounds
# the value of fitness:  0.612179696559906
# within bounds
# the value of fitness:  0.612710177898407
# within bounds
# the value of fitness:  0.6180687546730042
# within bounds
# the value of fitness:  0.6180687546730042
# within bounds
# the value of fitness:  0.6181866824626923
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6182167232036591
# within bounds
# the value of fitness:  0.6192940771579742
# within bounds
# the value of fitness:  0.6192940771579742
# within bounds
# the value of fitness:  0.6192940771579742
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6236936450004578
# within bounds
# the value of fitness:  0.6260049641132355
# within bounds
# the value of fitness:  0.6260049641132355
# within bounds
# the value of fitness:  0.6272206902503967
# within bounds
# the value of fitness:  0.6272206902503967
# within bounds
# the value of fitness:  0.6272206902503967
# within bounds
# the value of fitness:  0.6275490820407867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.6291379928588867
# within bounds
# the value of fitness:  0.633345365524292
# within bounds
# the value of fitness:  0.633375495672226
# within bounds
# the value of fitness:  0.6338758170604706
# within bounds
# the value of fitness:  0.6338758170604706
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6345503926277161
# within bounds
# the value of fitness:  0.6350804567337036
# within bounds
# the value of fitness:  0.6350804567337036
# within bounds
# the value of fitness:  0.6350804567337036
# within bounds
# the value of fitness:  0.6350804567337036
# within bounds
# the value of fitness:  0.6350804567337036
# within bounds
# the value of fitness:  0.6378123462200165
# within bounds
# the value of fitness:  0.6387788355350494
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6399295926094055
# within bounds
# the value of fitness:  0.6416448652744293
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6416740417480469
# within bounds
# the value of fitness:  0.6419395208358765
# within bounds
# the value of fitness:  0.6419395208358765
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6428681015968323
# within bounds
# the value of fitness:  0.6440834701061249
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.645273357629776
# within bounds
# the value of fitness:  0.6478478610515594
# within bounds
# the value of fitness:  0.6478478610515594
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.6490322351455688
# within bounds
# the value of fitness:  0.649369865655899
# within bounds
# the value of fitness:  0.649369865655899
# within bounds
# the value of fitness:  0.649369865655899
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6493991911411285
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.6494283974170685
# within bounds
# the value of fitness:  0.64943727850914
# within bounds
# the value of fitness:  0.64943727850914
# within bounds
# the value of fitness:  0.6494571566581726
# within bounds
# the value of fitness:  0.6494571566581726
# within bounds
# the value of fitness:  0.650522768497467
# within bounds
# the value of fitness:  0.650522768497467
# within bounds
# the value of fitness:  0.650522768497467
# within bounds
# the value of fitness:  0.6505424082279205
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.6505514979362488
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.650580883026123
# within bounds
# the value of fitness:  0.6506102383136749
# within bounds
# the value of fitness:  0.6517221927642822
# within bounds
# the value of fitness:  0.6517221927642822
# within bounds
# the value of fitness:  0.6535744667053223
# within bounds
# the value of fitness:  0.657046377658844
# within bounds
# the value of fitness:  0.657046377658844
# within bounds
# the value of fitness:  0.6582156121730804
# within bounds
# the value of fitness:  0.6582156121730804
# within bounds
# the value of fitness:  0.6582156121730804
# within bounds
# the value of fitness:  0.6629771888256073
# within bounds
# the value of fitness:  0.6646130084991455
# within bounds
# the value of fitness:  0.6657696068286896
# within bounds
# the value of fitness:  0.6657696068286896
# within bounds
# the value of fitness:  0.6657696068286896
# within bounds
# the value of fitness:  0.6666219532489777
# within bounds
# the value of fitness:  0.6720958352088928
# within bounds
# the value of fitness:  0.6720958352088928
# within bounds
# the value of fitness:  0.6732394993305206
# within bounds
# the value of fitness:  0.6773402392864227
# within bounds
# the value of fitness:  0.6794919967651367
# within bounds
# the value of fitness:  0.6794919967651367
# within bounds
# the value of fitness:  0.6806224584579468
# within bounds
# the value of fitness:  0.6806224584579468
# within bounds
# the value of fitness:  0.6806224584579468
# within bounds
# the value of fitness:  0.6832696497440338
# within bounds
# the value of fitness:  0.6867999732494354
# within bounds
# the value of fitness:  0.6878889501094818
# within bounds
# the value of fitness:  0.687916100025177
# within bounds
# the value of fitness:  0.687916100025177
# within bounds
# the value of fitness:  0.6905483603477478
# within bounds
# the value of fitness:  0.6951175034046173
# within bounds
# the value of fitness:  0.6951175034046173
# within bounds
# the value of fitness:  0.6951175034046173
# within bounds
# the value of fitness:  0.697834849357605
# within bounds
# the value of fitness:  0.7010887563228607
# within bounds
# the value of fitness:  0.707831084728241
# within bounds
# the value of fitness:  0.7080411911010742
# within bounds
# the value of fitness:  0.7092355191707611
# within bounds
# the value of fitness:  0.7092355191707611
# within bounds
# the value of fitness:  0.7100345492362976
# within bounds
# the value of fitness:  0.714762806892395
# within bounds
# the value of fitness:  0.7150913774967194
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.7161486148834229
# within bounds
# the value of fitness:  0.8029906749725342
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
# out of bounds
# the value of fitness:  10000.0
